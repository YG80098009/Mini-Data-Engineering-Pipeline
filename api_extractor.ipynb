# %%
import requests
from datetime import datetime

# --------- Helper: Geocoding ----------
def fetch_coordinates(location_name: str):
    url = "https://geocoding-api.open-meteo.com/v1/search"
    params = {
        "name": location_name,
        "count": 1
    }

    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json()

    if "results" not in data or not data["results"]:
        raise ValueError(f"Location not found: {location_name}")

    result = data["results"][0]
    return {
        "location_name": result["name"],
        "country": result.get("country"),
        "latitude": result["latitude"],
        "longitude": result["longitude"]
    }


# --------- Helper: Weather ----------
def fetch_hourly_weather(latitude: float, longitude: float):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "hourly": "temperature_2m,wind_speed_10m,relative_humidity_2m",
        "past_days": 1,
        "timezone": "UTC"
    }

    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json()["hourly"]


# --------- Main Ingestion Logic ----------
def ingest_weather_for_location(location_name):
    records = []


    # 1. Get coordinates
    location = fetch_coordinates(location_name)

    # 2. Get weather data
    hourly_data = fetch_hourly_weather(
        location["latitude"],
        location["longitude"]
    )

    times = hourly_data["time"]
    temperatures = hourly_data["temperature_2m"]
    wind_speeds = hourly_data["wind_speed_10m"]
    humidities = hourly_data["relative_humidity_2m"]

    # 3. Flatten to records (ONE record per hour per location)
    for i in range(len(times)):
        record = {
            "timestamp": datetime.fromisoformat(times[i]),
            "location_name": location["location_name"],
            "country": location["country"],
            "latitude": location["latitude"],
            "longitude": location["longitude"],
            "temperature": temperatures[i],
            "wind_speed": wind_speeds[i],
            "humidity": humidities[i]

        }
        records.append(record)

    return records

# %%
import requests

# נתוני דוגמה גולמיים
test_data = [{
    "timestamp": "2026-01-21T10:00:00",
    "location_name": "London",
    "country": "United Kingdom",
    "latitude": 51.5,
    "longitude": -0.12,
    "temperature": 26.5, # אמור להפוך ל-hot
    "wind_speed": 15.0,  # אמור להפוך ל-windy
    "humidity": 80
}]

# שליחה ל-Service B
response = requests.post("http://localhost:8002/clean", json=test_data)
print(f"Status Code: {response.status_code}")
print(f"Response: {response.json()}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:494, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     493     self.putheader(header, value)
# --> 494 self.endheaders()
#     496 # If we're given a body we start sending that in chunks.
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:325, in HTTPConnection.connect(self)
#     324 def connect(self) -> None:
# --> 325     self.sock = self._new_conn()
#     326     if self._tunnel_host:
#     327         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002E2AFCF5BE0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=8002): Max retries exceeded with url: /clean (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002E2AFCF5BE0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 16
#       4 test_data = [{
#       5     "timestamp": "2026-01-21T10:00:00",
#       6     "location_name": "London",
#    (...)     12     "humidity": 80
#      13 }]
#      15 # שליחה ל-Service B
# ---> 16 response = requests.post("http://localhost:8002/clean", json=test_data)
#      17 print(f"Status Code: {response.status_code}")
#      18 print(f"Response: {response.json()}")
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\יהודה גבריאלי\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     673     if isinstance(e.reason, _SSLError):
#     674         # This branch is for urllib3 v1.22 and later.
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#     680     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=8002): Max retries exceeded with url: /clean (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002E2AFCF5BE0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))

# %%
# this triggers the whole pipeline to ingest weather for London and write to mysql
data = ingest_weather_for_location("London")
data
# Out:
# [{'timestamp': datetime.datetime(2026, 1, 19, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.6,
#   'wind_speed': 3.9,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 19, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.2,
#   'wind_speed': 3.4,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 19, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.1,
#   'wind_speed': 3.1,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 19, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.1,
#   'wind_speed': 2.6,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 19, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.1,
#   'wind_speed': 3.9,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 19, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.9,
#   'wind_speed': 3.8,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 19, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.1,
#   'wind_speed': 4.0,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 19, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.2,
#   'wind_speed': 4.3,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 19, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.5,
#   'wind_speed': 3.6,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 19, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.9,
#   'wind_speed': 5.6,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 19, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.1,
#   'wind_speed': 6.7,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 19, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.4,
#   'wind_speed': 7.9,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 19, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.1,
#   'wind_speed': 9.5,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 19, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.8,
#   'wind_speed': 10.1,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 19, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 11.3,
#   'wind_speed': 13.4,
#   'humidity': 76},
#  {'timestamp': datetime.datetime(2026, 1, 19, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 11.0,
#   'wind_speed': 11.0,
#   'humidity': 77},
#  {'timestamp': datetime.datetime(2026, 1, 19, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.7,
#   'wind_speed': 9.4,
#   'humidity': 78},
#  {'timestamp': datetime.datetime(2026, 1, 19, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.2,
#   'wind_speed': 9.0,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 19, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 8.0,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 19, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 8.2,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 19, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 8.7,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 19, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.8,
#   'wind_speed': 7.9,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 19, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.0,
#   'wind_speed': 9.8,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 19, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.0,
#   'wind_speed': 9.3,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 20, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 11.3,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 20, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 10.3,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 20, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 9.5,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 20, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 10.7,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 20, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.7,
#   'wind_speed': 10.4,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 20, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.4,
#   'wind_speed': 12.3,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 20, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.1,
#   'wind_speed': 12.3,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 20, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.8,
#   'wind_speed': 12.5,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 20, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.8,
#   'wind_speed': 12.2,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 20, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.0,
#   'wind_speed': 11.0,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 20, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.2,
#   'wind_speed': 12.9,
#   'humidity': 75},
#  {'timestamp': datetime.datetime(2026, 1, 20, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.9,
#   'wind_speed': 19.7,
#   'humidity': 70},
#  {'timestamp': datetime.datetime(2026, 1, 20, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.5,
#   'wind_speed': 18.4,
#   'humidity': 66},
#  {'timestamp': datetime.datetime(2026, 1, 20, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.5,
#   'wind_speed': 20.5,
#   'humidity': 66},
#  {'timestamp': datetime.datetime(2026, 1, 20, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.5,
#   'wind_speed': 19.8,
#   'humidity': 63},
#  {'timestamp': datetime.datetime(2026, 1, 20, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.4,
#   'wind_speed': 20.1,
#   'humidity': 60},
#  {'timestamp': datetime.datetime(2026, 1, 20, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.8,
#   'wind_speed': 15.9,
#   'humidity': 70},
#  {'timestamp': datetime.datetime(2026, 1, 20, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.2,
#   'wind_speed': 16.3,
#   'humidity': 77},
#  {'timestamp': datetime.datetime(2026, 1, 20, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.0,
#   'wind_speed': 16.6,
#   'humidity': 78},
#  {'timestamp': datetime.datetime(2026, 1, 20, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.9,
#   'wind_speed': 18.4,
#   'humidity': 77},
#  {'timestamp': datetime.datetime(2026, 1, 20, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.1,
#   'wind_speed': 20.6,
#   'humidity': 77},
#  {'timestamp': datetime.datetime(2026, 1, 20, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.3,
#   'wind_speed': 16.8,
#   'humidity': 75},
#  {'timestamp': datetime.datetime(2026, 1, 20, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.1,
#   'wind_speed': 16.4,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 20, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.9,
#   'wind_speed': 15.5,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 21, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.6,
#   'wind_speed': 15.9,
#   'humidity': 78},
#  {'timestamp': datetime.datetime(2026, 1, 21, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.4,
#   'wind_speed': 15.9,
#   'humidity': 77},
#  {'timestamp': datetime.datetime(2026, 1, 21, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.3,
#   'wind_speed': 14.8,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 21, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.1,
#   'wind_speed': 10.1,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 21, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.9,
#   'wind_speed': 9.8,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 21, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.5,
#   'wind_speed': 10.2,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 21, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.2,
#   'wind_speed': 8.3,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 21, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.9,
#   'wind_speed': 6.6,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 21, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.8,
#   'wind_speed': 8.4,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 21, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.7,
#   'wind_speed': 11.3,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 21, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.4,
#   'wind_speed': 14.2,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 21, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.5,
#   'wind_speed': 16.1,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 21, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.3,
#   'wind_speed': 17.4,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 21, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.9,
#   'wind_speed': 20.0,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 21, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.9,
#   'wind_speed': 20.1,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 21, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.7,
#   'wind_speed': 18.8,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 21, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.6,
#   'wind_speed': 19.5,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 21, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.9,
#   'wind_speed': 18.1,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 21, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.1,
#   'wind_speed': 17.1,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 21, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.2,
#   'wind_speed': 17.1,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 21, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.2,
#   'wind_speed': 16.3,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 21, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.1,
#   'wind_speed': 15.6,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 21, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.3,
#   'wind_speed': 15.4,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 21, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 10.0,
#   'wind_speed': 14.4,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 22, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.9,
#   'wind_speed': 11.7,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 22, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.7,
#   'wind_speed': 11.2,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 22, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.7,
#   'wind_speed': 11.2,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 22, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.8,
#   'wind_speed': 11.0,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 22, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.4,
#   'wind_speed': 12.2,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 22, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.0,
#   'wind_speed': 13.6,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 22, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.7,
#   'wind_speed': 13.7,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 22, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.2,
#   'wind_speed': 12.7,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 22, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.9,
#   'wind_speed': 10.6,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 22, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.7,
#   'wind_speed': 10.0,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 22, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.9,
#   'wind_speed': 10.2,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 22, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.4,
#   'wind_speed': 11.2,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 22, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.0,
#   'wind_speed': 12.3,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 22, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.2,
#   'wind_speed': 14.5,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 22, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.3,
#   'wind_speed': 14.0,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 22, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.3,
#   'wind_speed': 12.1,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 22, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 9.0,
#   'wind_speed': 11.6,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 22, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.4,
#   'wind_speed': 11.0,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 22, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.0,
#   'wind_speed': 10.7,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 22, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.8,
#   'wind_speed': 11.6,
#   'humidity': 90},
#  {'timestamp': datetime.datetime(2026, 1, 22, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.6,
#   'wind_speed': 11.6,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 22, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.6,
#   'wind_speed': 10.9,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 22, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.5,
#   'wind_speed': 9.2,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 22, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.3,
#   'wind_speed': 7.3,
#   'humidity': 96},
#  {'timestamp': datetime.datetime(2026, 1, 23, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.4,
#   'wind_speed': 7.8,
#   'humidity': 96},
#  {'timestamp': datetime.datetime(2026, 1, 23, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.7,
#   'wind_speed': 8.9,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 23, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.3,
#   'wind_speed': 8.0,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 23, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.5,
#   'wind_speed': 5.4,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 23, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.0,
#   'wind_speed': 6.4,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 23, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.9,
#   'wind_speed': 6.7,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 23, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.4,
#   'wind_speed': 7.5,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 23, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.4,
#   'wind_speed': 8.4,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 23, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.2,
#   'wind_speed': 9.2,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 23, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.4,
#   'wind_speed': 11.4,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 23, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.0,
#   'wind_speed': 14.4,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 23, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.6,
#   'wind_speed': 14.9,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 23, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.0,
#   'wind_speed': 16.3,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 23, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.1,
#   'wind_speed': 16.2,
#   'humidity': 80},
#  {'timestamp': datetime.datetime(2026, 1, 23, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.9,
#   'wind_speed': 15.3,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 23, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.7,
#   'wind_speed': 14.5,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 23, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.5,
#   'wind_speed': 14.4,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 23, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.2,
#   'wind_speed': 14.3,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 23, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.0,
#   'wind_speed': 14.5,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 23, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.9,
#   'wind_speed': 14.2,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 23, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.8,
#   'wind_speed': 13.7,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 23, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.8,
#   'wind_speed': 13.1,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 23, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.7,
#   'wind_speed': 12.8,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 23, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.6,
#   'wind_speed': 12.6,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 24, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.5,
#   'wind_speed': 12.1,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 24, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.3,
#   'wind_speed': 11.6,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 24, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.1,
#   'wind_speed': 11.1,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 24, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.9,
#   'wind_speed': 10.6,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 24, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.7,
#   'wind_speed': 10.6,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 24, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.6,
#   'wind_speed': 10.9,
#   'humidity': 90},
#  {'timestamp': datetime.datetime(2026, 1, 24, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.5,
#   'wind_speed': 10.9,
#   'humidity': 90},
#  {'timestamp': datetime.datetime(2026, 1, 24, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.4,
#   'wind_speed': 10.3,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 24, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.4,
#   'wind_speed': 9.9,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 24, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.7,
#   'wind_speed': 9.7,
#   'humidity': 90},
#  {'timestamp': datetime.datetime(2026, 1, 24, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.5,
#   'wind_speed': 10.7,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 24, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.6,
#   'wind_speed': 12.3,
#   'humidity': 78},
#  {'timestamp': datetime.datetime(2026, 1, 24, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.4,
#   'wind_speed': 13.1,
#   'humidity': 72},
#  {'timestamp': datetime.datetime(2026, 1, 24, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.7,
#   'wind_speed': 13.5,
#   'humidity': 69},
#  {'timestamp': datetime.datetime(2026, 1, 24, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.8,
#   'wind_speed': 13.1,
#   'humidity': 67},
#  {'timestamp': datetime.datetime(2026, 1, 24, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 8.5,
#   'wind_speed': 12.3,
#   'humidity': 67},
#  {'timestamp': datetime.datetime(2026, 1, 24, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.7,
#   'wind_speed': 10.2,
#   'humidity': 71},
#  {'timestamp': datetime.datetime(2026, 1, 24, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.7,
#   'wind_speed': 8.4,
#   'humidity': 78},
#  {'timestamp': datetime.datetime(2026, 1, 24, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.8,
#   'wind_speed': 8.3,
#   'humidity': 83},
#  {'timestamp': datetime.datetime(2026, 1, 24, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.2,
#   'wind_speed': 9.0,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 24, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.9,
#   'wind_speed': 9.7,
#   'humidity': 87},
#  {'timestamp': datetime.datetime(2026, 1, 24, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.6,
#   'wind_speed': 10.1,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 24, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.3,
#   'wind_speed': 10.1,
#   'humidity': 90},
#  {'timestamp': datetime.datetime(2026, 1, 24, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.0,
#   'wind_speed': 9.4,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 25, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.8,
#   'wind_speed': 9.1,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 25, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.6,
#   'wind_speed': 8.8,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 25, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.5,
#   'wind_speed': 8.9,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 25, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.4,
#   'wind_speed': 8.6,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 25, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.4,
#   'wind_speed': 8.3,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 25, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.4,
#   'wind_speed': 7.9,
#   'humidity': 95},
#  {'timestamp': datetime.datetime(2026, 1, 25, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.4,
#   'wind_speed': 7.6,
#   'humidity': 96},
#  {'timestamp': datetime.datetime(2026, 1, 25, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.6,
#   'wind_speed': 10.9,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 25, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.5,
#   'wind_speed': 10.4,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 25, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.6,
#   'wind_speed': 10.4,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 25, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.0,
#   'wind_speed': 10.4,
#   'humidity': 89},
#  {'timestamp': datetime.datetime(2026, 1, 25, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.6,
#   'wind_speed': 10.2,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 25, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.9,
#   'wind_speed': 10.4,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 25, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 7.0,
#   'wind_speed': 10.1,
#   'humidity': 85},
#  {'timestamp': datetime.datetime(2026, 1, 25, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.9,
#   'wind_speed': 10.1,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 25, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.8,
#   'wind_speed': 9.7,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 25, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.5,
#   'wind_speed': 9.1,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 25, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 6.1,
#   'wind_speed': 9.0,
#   'humidity': 88},
#  {'timestamp': datetime.datetime(2026, 1, 25, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.7,
#   'wind_speed': 8.4,
#   'humidity': 90},
#  {'timestamp': datetime.datetime(2026, 1, 25, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.5,
#   'wind_speed': 7.1,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 25, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.3,
#   'wind_speed': 5.7,
#   'humidity': 92},
#  {'timestamp': datetime.datetime(2026, 1, 25, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.1,
#   'wind_speed': 4.8,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 25, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.1,
#   'wind_speed': 4.7,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 25, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.2,
#   'wind_speed': 5.2,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 26, 0, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.1,
#   'wind_speed': 5.5,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 26, 1, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.8,
#   'wind_speed': 5.8,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 26, 2, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.3,
#   'wind_speed': 6.1,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 26, 3, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.8,
#   'wind_speed': 6.4,
#   'humidity': 93},
#  {'timestamp': datetime.datetime(2026, 1, 26, 4, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.3,
#   'wind_speed': 6.4,
#   'humidity': 94},
#  {'timestamp': datetime.datetime(2026, 1, 26, 5, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.8,
#   'wind_speed': 6.6,
#   'humidity': 95},
#  {'timestamp': datetime.datetime(2026, 1, 26, 6, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.4,
#   'wind_speed': 6.5,
#   'humidity': 96},
#  {'timestamp': datetime.datetime(2026, 1, 26, 7, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.3,
#   'wind_speed': 6.4,
#   'humidity': 96},
#  {'timestamp': datetime.datetime(2026, 1, 26, 8, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.3,
#   'wind_speed': 6.3,
#   'humidity': 96},
#  {'timestamp': datetime.datetime(2026, 1, 26, 9, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.6,
#   'wind_speed': 6.6,
#   'humidity': 95},
#  {'timestamp': datetime.datetime(2026, 1, 26, 10, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.5,
#   'wind_speed': 7.2,
#   'humidity': 91},
#  {'timestamp': datetime.datetime(2026, 1, 26, 11, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.8,
#   'wind_speed': 8.3,
#   'humidity': 86},
#  {'timestamp': datetime.datetime(2026, 1, 26, 12, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.6,
#   'wind_speed': 9.4,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 26, 13, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.6,
#   'wind_speed': 10.1,
#   'humidity': 77},
#  {'timestamp': datetime.datetime(2026, 1, 26, 14, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 5.3,
#   'wind_speed': 10.5,
#   'humidity': 74},
#  {'timestamp': datetime.datetime(2026, 1, 26, 15, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.9,
#   'wind_speed': 10.9,
#   'humidity': 72},
#  {'timestamp': datetime.datetime(2026, 1, 26, 16, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 4.4,
#   'wind_speed': 10.9,
#   'humidity': 73},
#  {'timestamp': datetime.datetime(2026, 1, 26, 17, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.7,
#   'wind_speed': 10.9,
#   'humidity': 76},
#  {'timestamp': datetime.datetime(2026, 1, 26, 18, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 3.2,
#   'wind_speed': 10.2,
#   'humidity': 78},
#  {'timestamp': datetime.datetime(2026, 1, 26, 19, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.9,
#   'wind_speed': 9.3,
#   'humidity': 79},
#  {'timestamp': datetime.datetime(2026, 1, 26, 20, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.8,
#   'wind_speed': 7.8,
#   'humidity': 81},
#  {'timestamp': datetime.datetime(2026, 1, 26, 21, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.6,
#   'wind_speed': 7.1,
#   'humidity': 82},
#  {'timestamp': datetime.datetime(2026, 1, 26, 22, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.4,
#   'wind_speed': 7.2,
#   'humidity': 84},
#  {'timestamp': datetime.datetime(2026, 1, 26, 23, 0),
#   'location_name': 'London',
#   'country': 'United Kingdom',
#   'latitude': 51.50853,
#   'longitude': -0.12574,
#   'temperature': 2.2,
#   'wind_speed': 7.4,
#   'humidity': 85}]
